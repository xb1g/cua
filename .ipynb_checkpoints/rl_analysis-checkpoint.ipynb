# %% [markdown]
# # AEGIS RL Analysis
#
# Portfolio-ready analysis of AEGIS trajectory logs. This notebook loads `trajectories/*.json`, validates each run with the `RunResult` Pydantic schema, computes reward features, and visualizes reliability, efficiency, and reward quality over time.

# %% [markdown]
# ## Setup
#
# Run from the repository root so imports resolve against local source.

# %%
from __future__ import annotations

import json
import re
import sys
from pathlib import Path

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

ROOT = Path.cwd()
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from cua_loop.rl import reward_from_attempt
from cua_loop.types import RunResult

sns.set_theme(style="whitegrid", context="talk")
plt.rcParams["figure.figsize"] = (12, 6)
plt.rcParams["axes.titleweight"] = "bold"

# %% [markdown]
# ## Load and Validate Trajectories
#
# Only files that validate as `RunResult` are included. Other JSON files, such as policy snapshots, are skipped.

# %%
TRAJ_DIR = ROOT / "trajectories"
json_files = sorted(TRAJ_DIR.glob("*.json"))
runs: list[tuple[Path, RunResult]] = []
skipped: list[tuple[str, str]] = []

for path in json_files:
    try:
        runs.append((path, RunResult.model_validate_json(path.read_text())))
    except Exception as exc:
        skipped.append((path.name, type(exc).__name__))

print(f"Found {len(json_files)} JSON files in {TRAJ_DIR}")
print(f"Loaded {len(runs)} valid RunResult files; skipped {len(skipped)} files")
if skipped:
    display(pd.DataFrame(skipped, columns=["file", "reason"]))
# Out:
# Found 53 JSON files in /mnt/c/Users/EGHI0/OneDrive/Documents/x1bg/cua/trajectories
# Loaded 52 valid RunResult files; skipped 1 files
#                    file           reason
# 0  aegis-rl-policy.json  ValidationError

# %% [markdown]
# ## Flatten Runs Into Attempt-Level Rows
#
# Reward is recomputed from `cua_loop.rl.reward_from_attempt` so the notebook stays aligned with the training code. Strategy labels are inferred from step messages when available; otherwise they are marked `unknown`.

# %%
def infer_strategy(attempt) -> str:
    text_parts = []
    if attempt.trajectory.final_message:
        text_parts.append(attempt.trajectory.final_message)
    for step in attempt.trajectory.steps:
        if step.model_message:
            text_parts.append(step.model_message)
        if step.verification_reason:
            text_parts.append(step.verification_reason)
    text = "\n".join(text_parts)
    match = re.search(r"AEGIS RL strategy:\s*([a-zA-Z0-9_\-]+)", text)
    return match.group(1) if match else "unknown"

records = []
for run_idx, (path, run) in enumerate(runs):
    ts = pd.to_datetime(path.stat().st_mtime, unit="s")
    for attempt in run.attempts:
        steps = len(attempt.trajectory.steps)
        failed_steps = sum(step.verification_passed is False for step in attempt.trajectory.steps)
        blocked_steps = sum(step.blocked for step in attempt.trajectory.steps)
        records.append({
            "file": path.name,
            "timestamp": ts,
            "run_index": run_idx,
            "task": run.task,
            "url": run.url,
            "run_success": run.success,
            "attempt_index": attempt.attempt_index,
            "attempt_success": attempt.verifier.success,
            "schema_valid": attempt.verifier.schema_valid,
            "rows_extracted": attempt.verifier.rows_extracted,
            "steps": steps,
            "failed_verification_steps": failed_steps,
            "blocked_steps": blocked_steps,
            "duration_s": attempt.duration_s,
            "reward": reward_from_attempt(attempt),
            "strategy": infer_strategy(attempt),
            "reason": attempt.verifier.reason,
        })

df = pd.DataFrame(records)
if df.empty:
    print("No valid trajectory attempts yet. Run `uv run cua-loop ...` or `uv run aegis-rl ...` to generate logs.")
else:
    df = df.sort_values(["timestamp", "run_index", "attempt_index"]).reset_index(drop=True)
    display(df.head())
    display(df.describe(include="all"))
# Out:
#                   file                     timestamp  run_index  \
# 0  run-1778356579.json 2026-05-09 19:56:19.319287777         50
# 1  run-1778356579.json 2026-05-09 19:56:19.319287777         50
# 2  run-1778356579.json 2026-05-09 19:56:19.319287777         50
# 3  run-1778356579.json 2026-05-09 19:56:19.319287777         50
# 4  run-1778356579.json 2026-05-09 19:56:19.319287777         50
#
#                                              task  \
# 0  find me the best deal on bestbuy for a macbook
# 1  find me the best deal on bestbuy for a macbook
# 2  find me the best deal on bestbuy for a macbook
# 3  find me the best deal on bestbuy for a macbook
# 4  find me the best deal on bestbuy for a macbook
#
#                                                  url  run_success  \
# 0  https://www.bestbuy.com/home?ref=212&loc=63907...        False
# 1  https://www.bestbuy.com/home?ref=212&loc=63907...        False
# 2  https://www.bestbuy.com/home?ref=212&loc=63907...        False
# 3  https://www.bestbuy.com/home?ref=212&loc=63907...        False
# 4  https://www.bestbuy.com/home?ref=212&loc=63907...        False
#
#    attempt_index  attempt_success  schema_valid  rows_extracted  steps  \
# 0              0            False         False               0      0
# 1              1            False         False               0      0
# 2              2            False         False               0      0
# 3              3            False         False               0      0
# 4              4            False         False               0      0
#
#    failed_verification_steps  blocked_steps  duration_s  reward strategy  \
# 0                          0              0   15.927920     0.5  unknown
# 1                          0              0    0.770322     0.5  unknown
# 2                          0              0    0.864381     0.5  unknown
# 3                          0              0    0.863280     0.5  unknown
# 4                          0              0    0.814492     0.5  unknown
#
#                                               reason
# 0  verifier API error: AuthenticationError: Error...
# 1  verifier API error: AuthenticationError: Error...
# 2  verifier API error: AuthenticationError: Error...
# 3  verifier API error: AuthenticationError: Error...
# 4  verifier API error: AuthenticationError: Error...
#                        file                      timestamp  run_index  \
# count                    60                             60  60.000000
# unique                   52                            NaN        NaN
# top     run-1778356579.json                            NaN        NaN
# freq                      5                            NaN        NaN
# mean                    NaN     2026-05-09 21:50:01.225696  28.833333
# min                     NaN  2026-05-09 19:56:19.319287777   0.000000
# 25%                     NaN  2026-05-09 22:12:42.292083968  14.750000
# 50%                     NaN  2026-05-09 22:12:42.509267968  29.500000
# 75%                     NaN  2026-05-09 22:12:42.700069888  44.250000
# max                     NaN  2026-05-09 22:12:42.865177393  51.000000
# std                     NaN                            NaN  16.492594
#
#                          task                                           url  \
# count                      60                                            60
# unique                      4                                             4
# top     Find macbooks on ebay  https://www.ebay.com/sch/i.html?_nkw=macbook
# freq                       18                                            18
# mean                      NaN                                           NaN
# min                       NaN                                           NaN
# 25%                       NaN                                           NaN
# 50%                       NaN                                           NaN
# 75%                       NaN                                           NaN
# max                       NaN                                           NaN
# std                       NaN                                           NaN
#
#        run_success  attempt_index attempt_success schema_valid  \
# count           60      60.000000              60           60
# unique           2            NaN               2            2
# top           True            NaN            True         True
# freq            50            NaN              50           50
# mean           NaN       0.333333             NaN          NaN
# min            NaN       0.000000             NaN          NaN
# 25%            NaN       0.000000             NaN          NaN
# 50%            NaN       0.000000             NaN          NaN
# 75%            NaN       0.000000             NaN          NaN
# max            NaN       4.000000             NaN          NaN
# std            NaN       0.950765             NaN          NaN
#
#         rows_extracted      steps  failed_verification_steps  blocked_steps  \
# count         60.00000  60.000000                       60.0           60.0
# unique             NaN        NaN                        NaN            NaN
# top                NaN        NaN                        NaN            NaN
# freq               NaN        NaN                        NaN            NaN
# mean           7.70000   2.500000                        0.0            0.0
# min            0.00000   0.000000                        0.0            0.0
# 25%            4.00000   3.000000                        0.0            0.0
# 50%            8.00000   3.000000                        0.0            0.0
# 75%           12.00000   3.000000                        0.0            0.0
# max           15.00000   3.000000                        0.0            0.0
# std            4.94478   1.127469                        0.0            0.0
#
#         duration_s     reward strategy  \
# count    60.000000  60.000000       60
# unique         NaN        NaN        1
# top            NaN        NaN  unknown
# freq           NaN        NaN       60
# mean     30.852780   1.873333      NaN
# min       0.770322   0.500000      NaN
# 25%      16.236511   1.950000      NaN
# 50%      34.462290   2.150000      NaN
# 75%      44.929801   2.250000      NaN
# max      59.788177   2.250000      NaN
# std      17.799948   0.630339      NaN
#
#                                                    reason
# count                                                  60
# unique                                                 14
# top     verifier API error: AuthenticationError: Error...
# freq                                                   10
# mean                                                  NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
# std                                                   NaN

# %% [markdown]
# ## Success Rate Over Time

# %%
if not df.empty:
    run_df = df.groupby(["file", "timestamp", "run_index"], as_index=False).agg(run_success=("run_success", "max"))
    run_df = run_df.sort_values("timestamp").reset_index(drop=True)
    run_df["run_number"] = run_df.index + 1
    run_df["cumulative_success_rate"] = run_df["run_success"].expanding().mean()

    ax = sns.lineplot(data=run_df, x="run_number", y="cumulative_success_rate", marker="o")
    ax.set_title("AEGIS Success Rate Over Time")
    ax.set_xlabel("Run Number")
    ax.set_ylabel("Cumulative Success Rate")
    ax.set_ylim(0, 1.05)
    plt.show()
else:
    print("No data to plot.")

# %% [markdown]
# ## Average Steps Per Attempt

# %%
if not df.empty:
    steps_by_run = df.groupby("run_index", as_index=False).agg(avg_steps=("steps", "mean"), success_rate=("attempt_success", "mean"))
    fig, ax1 = plt.subplots(figsize=(12, 6))
    sns.barplot(data=steps_by_run, x="run_index", y="avg_steps", color="#4C78A8", ax=ax1)
    ax1.set_title("Average Steps Per Attempt by Run")
    ax1.set_xlabel("Run Index")
    ax1.set_ylabel("Average Steps")
    ax2 = ax1.twinx()
    sns.lineplot(data=steps_by_run, x="run_index", y="success_rate", color="#F58518", marker="o", ax=ax2)
    ax2.set_ylabel("Attempt Success Rate")
    ax2.set_ylim(0, 1.05)
    plt.show()
else:
    print("No data to plot.")

# %% [markdown]
# ## Reward Distribution Per Strategy

# %%
if not df.empty:
    plt.figure(figsize=(12, 6))
    ax = sns.violinplot(data=df, x="strategy", y="reward", inner="quartile", cut=0)
    sns.stripplot(data=df, x="strategy", y="reward", color="black", alpha=0.35, size=4, ax=ax)
    ax.set_title("Reward Distribution by Search Strategy")
    ax.set_xlabel("Strategy")
    ax.set_ylabel("Raw Reward")
    plt.xticks(rotation=20, ha="right")
    plt.show()
else:
    print("No data to plot.")

# %% [markdown]
# ## Correlation Heatmap
#
# Correlation between action count, reward, extracted rows, duration, blocked steps, and failed verification steps.

# %%
if not df.empty:
    corr_cols = ["steps", "reward", "rows_extracted", "duration_s", "blocked_steps", "failed_verification_steps"]
    corr = df[corr_cols].corr(numeric_only=True)
    plt.figure(figsize=(10, 8))
    ax = sns.heatmap(corr, annot=True, fmt=".2f", cmap="vlag", center=0, square=True, linewidths=0.5)
    ax.set_title("Trajectory Metrics Correlation Heatmap")
    plt.show()
else:
    print("No data to plot.")

# %% [markdown]
# ## Strategy Leaderboard

# %%
if not df.empty:
    leaderboard = (
        df.groupby("strategy", as_index=False)
        .agg(
            attempts=("strategy", "size"),
            success_rate=("attempt_success", "mean"),
            mean_reward=("reward", "mean"),
            median_steps=("steps", "median"),
            mean_rows=("rows_extracted", "mean"),
        )
        .sort_values(["mean_reward", "success_rate"], ascending=False)
    )
    display(leaderboard.style.format({"success_rate": "{:.1%}", "mean_reward": "{:.3f}", "median_steps": "{:.1f}", "mean_rows": "{:.1f}"}))
else:
    print("No strategy leaderboard yet.")
# Out:
# <style type="text/css">
# </style>
# <table id="T_da0f2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_da0f2_level0_col0" class="col_heading level0 col0" >strategy</th>
#       <th id="T_da0f2_level0_col1" class="col_heading level0 col1" >attempts</th>
#       <th id="T_da0f2_level0_col2" class="col_heading level0 col2" >success_rate</th>
#       <th id="T_da0f2_level0_col3" class="col_heading level0 col3" >mean_reward</th>
#       <th id="T_da0f2_level0_col4" class="col_heading level0 col4" >median_steps</th>
#       <th id="T_da0f2_level0_col5" class="col_heading level0 col5" >mean_rows</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_da0f2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_da0f2_row0_col0" class="data row0 col0" >unknown</td>
#       <td id="T_da0f2_row0_col1" class="data row0 col1" >60</td>
#       <td id="T_da0f2_row0_col2" class="data row0 col2" >83.3%</td>
#       <td id="T_da0f2_row0_col3" class="data row0 col3" >1.873</td>
#       <td id="T_da0f2_row0_col4" class="data row0 col4" >3.0</td>
#       <td id="T_da0f2_row0_col5" class="data row0 col5" >7.7</td>
#     </tr>
#   </tbody>
# </table>
